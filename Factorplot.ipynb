# %%
#Importing required packages
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('data.csv')
df['Gene 1']="Lgals4"
df['Gene 2']="Kif2c"

# %%
df.head()
# Out:
#   sample  Time      Lgals4      Kif2c  Gene 1 Gene 2
# 0     S1     9  445.324993  32.795454  Lgals4  Kif2c
# 1     S2     9  328.836556  24.356969  Lgals4  Kif2c
# 2     S3     9  247.983610  21.152797  Lgals4  Kif2c
# 3     S4     7  307.191034  28.315431  Lgals4  Kif2c
# 4     S5     7  210.447295  35.192365  Lgals4  Kif2c

# %%
# Draw a pointplot to show pulse
g = sns.factorplot(x="Time", y="Lgals4", hue='Gene 1' ,data=df,
                   capsize=.2 ,size=7)
g = sns.factorplot(x="Time", y="Kif2c", hue='Gene 2' ,data=df,
                   capsize=.2,size=7)
plt.show()
